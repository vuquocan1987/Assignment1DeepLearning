# %%
# load the dataset from the csv file using pandas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras import regularizers
from keras import optimizers
from keras import backend as K
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score

# load the dataset from the csv file using pandas
df = pd.read_csv('diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 0            6      148             72             35        0  33.6  \
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Replace the 0 values with NA except for the [Pregnancies, Outcome, DiabetesPedigreeFunction, Age] columns
df_copy = df.copy(deep = True)
df_copy[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']] = df_copy[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']].replace(0, np.NaN)
df_copy.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 0            6    148.0           72.0           35.0      NaN  33.6  \
# 1            1     85.0           66.0           29.0      NaN  26.6
# 2            8    183.0           64.0            NaN      NaN  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# impute missing values with KNN imputer
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=5)
df_filled = imputer.fit_transform(df_copy)
df_filled = pd.DataFrame(df_filled, columns = df_copy.columns)
df_filled.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 0          6.0    148.0           72.0           35.0    169.0  33.6  \
# 1          1.0     85.0           66.0           29.0     58.6  26.6
# 2          8.0    183.0           64.0           25.8    164.6  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          0.0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.627  50.0      1.0
# 1                     0.351  31.0      0.0
# 2                     0.672  32.0      1.0
# 3                     0.167  21.0      0.0
# 4                     2.288  33.0      1.0

# %%
# check if there are any null values
df_filled.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# scale the data using min_max except for outcome column
df_copy_scaled = df_copy.copy(deep = True)
df_copy_scaled[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']] = df_copy_scaled[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']].apply(lambda x: (x - x.min()) / (x.max() - x.min()))

# %%
# Split the data into training and test sets
X = df_copy_scaled.drop(columns = ['Outcome'])
y = df_copy_scaled['Outcome']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state=5)

# %%
# create a deep learning model with 3 hidden layers
model = Sequential([
    Dense(8, activation = 'relu', input_shape = (8,)),
    Dense(4, activation = 'relu'),
    Dense(2, activation = 'relu'),
    Dense(1, activation = 'sigmoid'),
])
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
def create_model():
    model = Sequential([
        Dense(8, activation = 'relu', input_shape = (8,)),
        Dense(4, activation = 'relu'),
        Dense(2, activation = 'relu'),
        Dense(1, activation = 'sigmoid'),
    ])
    model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    return model

# %%
y_train.dtype
# Out:
# dtype('int64')

# %%
# train the model
earlystoping = EarlyStopping(monitor = 'loss', mode = 'min', verbose = 1, patience = 100)
model.fit(X_train, y_train, epochs = 1000, validation_split = 0.1, verbose = 2, callbacks=[earlystoping])
# Out:
# Epoch 1/1000
# 2023-09-26 05:13:25.403666: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 20/20 - 1s - loss: 0.6883 - accuracy: 0.6425 - val_loss: 0.6812 - val_accuracy: 0.6857 - 755ms/epoch - 38ms/step
# Epoch 2/1000
# 20/20 - 0s - loss: 0.6808 - accuracy: 0.6425 - val_loss: 0.6708 - val_accuracy: 0.6857 - 166ms/epoch - 8ms/step
# Epoch 3/1000
# 20/20 - 0s - loss: 0.6736 - accuracy: 0.6425 - val_loss: 0.6612 - val_accuracy: 0.6857 - 160ms/epoch - 8ms/step
# Epoch 4/1000
# 20/20 - 0s - loss: 0.6671 - accuracy: 0.6425 - val_loss: 0.6536 - val_accuracy: 0.6857 - 163ms/epoch - 8ms/step
# Epoch 5/1000
# 20/20 - 0s - loss: 0.6623 - accuracy: 0.6425 - val_loss: 0.6460 - val_accuracy: 0.6857 - 159ms/epoch - 8ms/step
# Epoch 6/1000
# 20/20 - 0s - loss: 0.6586 - accuracy: 0.6425 - val_loss: 0.6405 - val_accuracy: 0.6857 - 155ms/epoch - 8ms/step
# Epoch 7/1000
# 20/20 - 0s - loss: 0.6561 - accuracy: 0.6425 - val_loss: 0.6364 - val_accuracy: 0.6857 - 156ms/epoch - 8ms/step
# Epoch 8/1000
# 20/20 - 0s - loss: 0.6543 - accuracy: 0.6425 - val_loss: 0.6337 - val_accuracy: 0.6857 - 155ms/epoch - 8ms/step
# Epoch 9/1000
# 20/20 - 0s - loss: 0.6533 - accuracy: 0.6425 - val_loss: 0.6311 - val_accuracy: 0.6857 - 158ms/epoch - 8ms/step
# Epoch 10/1000
# 20/20 - 0s - loss: 0.6528 - accuracy: 0.6425 - val_loss: 0.6306 - val_accuracy: 0.6857 - 180ms/epoch - 9ms/step
# Epoch 11/1000
# 20/20 - 0s - loss: 0.6525 - accuracy: 0.6425 - val_loss: 0.6292 - val_accuracy: 0.6857 - 157ms/epoch - 8ms/step
# Epoch 12/1000
# 20/20 - 0s - loss: 0.6523 - accuracy: 0.6425 - val_loss: 0.6288 - val_accuracy: 0.6857 - 166ms/epoch - 8ms/step
# Epoch 13/1000
# 20/20 - 0s - loss: 0.6523 - accuracy: 0.6425 - val_loss: 0.6279 - val_accuracy: 0.6857 - 158ms/epoch - 8ms/step
# Epoch 14/1000
# 20/20 - 0s - loss: 0.6524 - accuracy: 0.6425 - val_loss: 0.6267 - val_accuracy: 0.6857 - 155ms/epoch - 8ms/step
# Epoch 15/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6270 - val_accuracy: 0.6857 - 156ms/epoch - 8ms/step
# Epoch 16/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6271 - val_accuracy: 0.6857 - 154ms/epoch - 8ms/step
# Epoch 17/1000
# 20/20 - 0s - loss: 0.6521 - accuracy: 0.6425 - val_loss: 0.6269 - val_accuracy: 0.6857 - 152ms/epoch - 8ms/step
# Epoch 18/1000
# 20/20 - 0s - loss: 0.6521 - accuracy: 0.6425 - val_loss: 0.6270 - val_accuracy: 0.6857 - 190ms/epoch - 10ms/step
# Epoch 19/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6266 - val_accuracy: 0.6857 - 155ms/epoch - 8ms/step
# Epoch 20/1000
# 20/20 - 0s - loss: 0.6521 - accuracy: 0.6425 - val_loss: 0.6268 - val_accuracy: 0.6857 - 152ms/epoch - 8ms/step
# Epoch 21/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6261 - val_accuracy: 0.6857 - 154ms/epoch - 8ms/step
# Epoch 22/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6260 - val_accuracy: 0.6857 - 151ms/epoch - 8ms/step
# Epoch 23/1000
# 20/20 - 0s - loss: 0.6521 - accuracy: 0.6425 - val_loss: 0.6266 - val_accuracy: 0.6857 - 152ms/epoch - 8ms/step
# Epoch 24/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6263 - val_accuracy: 0.6857 - 151ms/epoch - 8ms/step
# Epoch 25/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6267 - val_accuracy: 0.6857 - 177ms/epoch - 9ms/step
# Epoch 26/1000
# 20/20 - 0s - loss: 0.6521 - accuracy: 0.6425 - val_loss: 0.6263 - val_accuracy: 0.6857 - 158ms/epoch - 8ms/step
# Epoch 27/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6266 - val_accuracy: 0.6857 - 154ms/epoch - 8ms/step
# Epoch 28/1000
# 20/20 - 0s - loss: 0.6521 - accuracy: 0.6425 - val_loss: 0.6271 - val_accuracy: 0.6857 - 152ms/epoch - 8ms/step
# Epoch 29/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6262 - val_accuracy: 0.6857 - 154ms/epoch - 8ms/step
# Epoch 30/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6261 - val_accuracy: 0.6857 - 151ms/epoch - 8ms/step
# Epoch 31/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6265 - val_accuracy: 0.6857 - 153ms/epoch - 8ms/step
# Epoch 32/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6263 - val_accuracy: 0.6857 - 153ms/epoch - 8ms/step
# Epoch 33/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6265 - val_accuracy: 0.6857 - 154ms/epoch - 8ms/step
# Epoch 34/1000
# 20/20 - 0s - loss: 0.6521 - accuracy: 0.6425 - val_loss: 0.6270 - val_accuracy: 0.6857 - 154ms/epoch - 8ms/step
# Epoch 35/1000
# 20/20 - 0s - loss: 0.6521 - accuracy: 0.6425 - val_loss: 0.6269 - val_accuracy: 0.6857 - 154ms/epoch - 8ms/step
# Epoch 36/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6266 - val_accuracy: 0.6857 - 153ms/epoch - 8ms/step
# Epoch 37/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6264 - val_accuracy: 0.6857 - 154ms/epoch - 8ms/step
# Epoch 38/1000
# 20/20 - 0s - loss: 0.6521 - accuracy: 0.6425 - val_loss: 0.6269 - val_accuracy: 0.6857 - 166ms/epoch - 8ms/step
# Epoch 39/1000
# 20/20 - 0s - loss: 0.6521 - accuracy: 0.6425 - val_loss: 0.6266 - val_accuracy: 0.6857 - 153ms/epoch - 8ms/step
# Epoch 40/1000
# 20/20 - 0s - loss: 0.6521 - accuracy: 0.6425 - val_loss: 0.6268 - val_accuracy: 0.6857 - 176ms/epoch - 9ms/step
# Epoch 41/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6263 - val_accuracy: 0.6857 - 157ms/epoch - 8ms/step
# Epoch 42/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6262 - val_accuracy: 0.6857 - 157ms/epoch - 8ms/step
# Epoch 43/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6263 - val_accuracy: 0.6857 - 155ms/epoch - 8ms/step
# Epoch 44/1000
# 20/20 - 0s - loss: 0.6521 - accuracy: 0.6425 - val_loss: 0.6263 - val_accuracy: 0.6857 - 152ms/epoch - 8ms/step
# Epoch 45/1000
# 20/20 - 0s - loss: 0.6521 - accuracy: 0.6425 - val_loss: 0.6270 - val_accuracy: 0.6857 - 156ms/epoch - 8ms/step
# Epoch 46/1000
# 20/20 - 0s - loss: 0.6521 - accuracy: 0.6425 - val_loss: 0.6266 - val_accuracy: 0.6857 - 154ms/epoch - 8ms/step
# Epoch 47/1000
# 20/20 - 0s - loss: 0.6521 - accuracy: 0.6425 - val_loss: 0.6274 - val_accuracy: 0.6857 - 156ms/epoch - 8ms/step
# Epoch 48/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6271 - val_accuracy: 0.6857 - 154ms/epoch - 8ms/step
# Epoch 49/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6269 - val_accuracy: 0.6857 - 155ms/epoch - 8ms/step
# Epoch 50/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6269 - val_accuracy: 0.6857 - 153ms/epoch - 8ms/step
# Epoch 51/1000
# 20/20 - 0s - loss: 0.6521 - accuracy: 0.6425 - val_loss: 0.6263 - val_accuracy: 0.6857 - 154ms/epoch - 8ms/step
# Epoch 52/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6264 - val_accuracy: 0.6857 - 153ms/epoch - 8ms/step
# Epoch 53/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6266 - val_accuracy: 0.6857 - 155ms/epoch - 8ms/step
# Epoch 54/1000
# 20/20 - 0s - loss: 0.6521 - accuracy: 0.6425 - val_loss: 0.6267 - val_accuracy: 0.6857 - 156ms/epoch - 8ms/step
# Epoch 55/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6265 - val_accuracy: 0.6857 - 177ms/epoch - 9ms/step
# Epoch 56/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6267 - val_accuracy: 0.6857 - 158ms/epoch - 8ms/step
# Epoch 57/1000
# 20/20 - 0s - loss: 0.6523 - accuracy: 0.6425 - val_loss: 0.6261 - val_accuracy: 0.6857 - 155ms/epoch - 8ms/step
# Epoch 58/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6264 - val_accuracy: 0.6857 - 157ms/epoch - 8ms/step
# Epoch 59/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6268 - val_accuracy: 0.6857 - 159ms/epoch - 8ms/step
# Epoch 60/1000
# 20/20 - 0s - loss: 0.6521 - accuracy: 0.6425 - val_loss: 0.6273 - val_accuracy: 0.6857 - 160ms/epoch - 8ms/step
# Epoch 61/1000
# 20/20 - 0s - loss: 0.6522 - accuracy: 0.6425 - val_loss: 0.6275 - val_accuracy: 0.6857 - 168ms/epoch - 8ms/step
# Epoch 62/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6273 - val_accuracy: 0.6857 - 161ms/epoch - 8ms/step
# Epoch 63/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6268 - val_accuracy: 0.6857 - 161ms/epoch - 8ms/step
# Epoch 64/1000
# 20/20 - 0s - loss: 0.6521 - accuracy: 0.6425 - val_loss: 0.6267 - val_accuracy: 0.6857 - 157ms/epoch - 8ms/step
# Epoch 65/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6265 - val_accuracy: 0.6857 - 156ms/epoch - 8ms/step
# Epoch 66/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6264 - val_accuracy: 0.6857 - 155ms/epoch - 8ms/step
# Epoch 67/1000
# 20/20 - 0s - loss: 0.6521 - accuracy: 0.6425 - val_loss: 0.6269 - val_accuracy: 0.6857 - 195ms/epoch - 10ms/step
# Epoch 68/1000
# 20/20 - 0s - loss: 0.6521 - accuracy: 0.6425 - val_loss: 0.6263 - val_accuracy: 0.6857 - 159ms/epoch - 8ms/step
# Epoch 69/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6267 - val_accuracy: 0.6857 - 160ms/epoch - 8ms/step
# Epoch 70/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6267 - val_accuracy: 0.6857 - 155ms/epoch - 8ms/step
# Epoch 71/1000
# 20/20 - 0s - loss: 0.6523 - accuracy: 0.6425 - val_loss: 0.6273 - val_accuracy: 0.6857 - 154ms/epoch - 8ms/step
# Epoch 72/1000
# 20/20 - 0s - loss: 0.6521 - accuracy: 0.6425 - val_loss: 0.6272 - val_accuracy: 0.6857 - 156ms/epoch - 8ms/step
# Epoch 73/1000
# 20/20 - 0s - loss: 0.6521 - accuracy: 0.6425 - val_loss: 0.6270 - val_accuracy: 0.6857 - 154ms/epoch - 8ms/step
# Epoch 74/1000
# 20/20 - 0s - loss: 0.6522 - accuracy: 0.6425 - val_loss: 0.6263 - val_accuracy: 0.6857 - 154ms/epoch - 8ms/step
# Epoch 75/1000
# 20/20 - 0s - loss: 0.6521 - accuracy: 0.6425 - val_loss: 0.6266 - val_accuracy: 0.6857 - 153ms/epoch - 8ms/step
# Epoch 76/1000
# 20/20 - 0s - loss: 0.6524 - accuracy: 0.6425 - val_loss: 0.6258 - val_accuracy: 0.6857 - 158ms/epoch - 8ms/step
# Epoch 77/1000
# 20/20 - 0s - loss: 0.6523 - accuracy: 0.6425 - val_loss: 0.6269 - val_accuracy: 0.6857 - 154ms/epoch - 8ms/step
# Epoch 78/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6264 - val_accuracy: 0.6857 - 157ms/epoch - 8ms/step
# Epoch 79/1000
# 20/20 - 0s - loss: 0.6521 - accuracy: 0.6425 - val_loss: 0.6266 - val_accuracy: 0.6857 - 157ms/epoch - 8ms/step
# Epoch 80/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6262 - val_accuracy: 0.6857 - 160ms/epoch - 8ms/step
# Epoch 81/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6265 - val_accuracy: 0.6857 - 196ms/epoch - 10ms/step
# Epoch 82/1000
# 20/20 - 0s - loss: 0.6522 - accuracy: 0.6425 - val_loss: 0.6268 - val_accuracy: 0.6857 - 163ms/epoch - 8ms/step
# Epoch 83/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6266 - val_accuracy: 0.6857 - 175ms/epoch - 9ms/step
# Epoch 84/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6262 - val_accuracy: 0.6857 - 162ms/epoch - 8ms/step
# Epoch 85/1000
# 20/20 - 0s - loss: 0.6521 - accuracy: 0.6425 - val_loss: 0.6260 - val_accuracy: 0.6857 - 166ms/epoch - 8ms/step
# Epoch 86/1000
# 20/20 - 0s - loss: 0.6521 - accuracy: 0.6425 - val_loss: 0.6264 - val_accuracy: 0.6857 - 157ms/epoch - 8ms/step
# Epoch 87/1000
# 20/20 - 0s - loss: 0.6520 - accuracy: 0.6425 - val_loss: 0.6263 - val_accuracy: 0.6857 - 156ms/epoch - 8ms/step
# Epoch 88/1000
# 20/20 - 0s - loss: 0.6521 - accuracy: 0.6425 - val_loss: 0.6265 - val_accuracy: 0.6857 - 157ms/epoch - 8ms/step
# Epoch 89/1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/anvu/Workspace/Master/DeepLearningFoundation/Diabetes-DeepLearning-KNNImpute.ipynb Cell 8 line 3
#       <a href='vscode-notebook-cell:/Users/anvu/Workspace/Master/DeepLearningFoundation/Diabetes-DeepLearning-KNNImpute.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> # train the model
#       <a href='vscode-notebook-cell:/Users/anvu/Workspace/Master/DeepLearningFoundation/Diabetes-DeepLearning-KNNImpute.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> earlystoping = EarlyStopping(monitor = 'loss', mode = 'min', verbose = 1, patience = 100)
# ----> <a href='vscode-notebook-cell:/Users/anvu/Workspace/Master/DeepLearningFoundation/Diabetes-DeepLearning-KNNImpute.ipynb#X22sZmlsZQ%3D%3D?line=2'>3</a> model.fit(X_train, y_train, epochs = 1000, batch_size = 32, validation_split = 0.1, verbose = 2, callbacks=[earlystoping])
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/keras/engine/training.py:1685, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1677 with tf.profiler.experimental.Trace(
#    1678     "train",
#    1679     epoch_num=epoch,
#    (...)
#    1682     _r=1,
#    1683 ):
#    1684     callbacks.on_train_batch_begin(step)
# -> 1685     tmp_logs = self.train_function(iterator)
#    1686     if data_handler.should_sync:
#    1687         context.async_wait()
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:894, in Function.__call__(self, *args, **kwds)
#     891 compiler = "xla" if self._jit_compile else "nonXla"
#     893 with OptionalXlaContext(self._jit_compile):
# --> 894   result = self._call(*args, **kwds)
#     896 new_tracing_count = self.experimental_get_tracing_count()
#     897 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:926, in Function._call(self, *args, **kwds)
#     923   self._lock.release()
#     924   # In this case we have created variables on the first call, so we run the
#     925   # defunned version which is guaranteed to never create variables.
# --> 926   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     927 elif self._variable_creation_fn is not None:
#     928   # Release the lock early so that multiple threads can perform the call
#     929   # in parallel.
#     930   self._lock.release()
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:143, in TracingCompiler.__call__(self, *args, **kwargs)
#     140 with self._lock:
#     141   (concrete_function,
#     142    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143 return concrete_function._call_flat(
#     144     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1757, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1753 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1754 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1755     and executing_eagerly):
#    1756   # No tape is watching; skip to running the function.
# -> 1757   return self._build_call_outputs(self._inference_function.call(
#    1758       ctx, args, cancellation_manager=cancellation_manager))
#    1759 forward_backward = self._select_forward_and_backward_functions(
#    1760     args,
#    1761     possible_gradient_type,
#    1762     executing_eagerly)
#    1763 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:381, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     379 with _InterpolateFunctionError(self):
#     380   if cancellation_manager is None:
# --> 381     outputs = execute.execute(
#     382         str(self.signature.name),
#     383         num_outputs=self._num_outputs,
#     384         inputs=args,
#     385         attrs=attrs,
#     386         ctx=ctx)
#     387   else:
#     388     outputs = execute.execute_with_cancellation(
#     389         str(self.signature.name),
#     390         num_outputs=self._num_outputs,
#    (...)
#     393         ctx=ctx,
#     394         cancellation_manager=cancellation_manager)
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:

# %%
model.evaluate(X_test, y_test, verbose = 2)
# Out:
# 3/3 - 0s - loss: 0.6249 - accuracy: 0.6883 - 60ms/epoch - 20ms/step
# [0.6249444484710693, 0.6883116960525513]

# %%
model.predict(X_test)
# Out:
# 3/3 [==============================] - 0s 7ms/step
# array([[0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358],
#        [0.35666358]], dtype=float32)

# %%
# do k-fold cross validation
from sklearn.model_selection import StratifiedKFold
kfold = StratifiedKFold(n_splits = 10, shuffle = True, random_state = 5)
cvscores = []
for train, test in kfold.split(X, y):
    model = create_model()
    earlystoping = EarlyStopping(monitor = 'loss', mode = 'min', verbose = 1, patience = 100)
    model.fit(X.iloc[train], y.iloc[train], epochs = 1000, batch_size = 32, verbose = 2, callbacks=[earlystoping])
    scores = model.evaluate(X.iloc[test], y.iloc[test], verbose = 0)
    print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1] * 100)
# Out:
# Epoch 1/1000
# 22/22 - 0s - loss: 0.6893 - accuracy: 0.6512 - 446ms/epoch - 20ms/step
# Epoch 2/1000
# 22/22 - 0s - loss: 0.6810 - accuracy: 0.6512 - 124ms/epoch - 6ms/step
# Epoch 3/1000
# 22/22 - 0s - loss: 0.6737 - accuracy: 0.6512 - 121ms/epoch - 5ms/step
# Epoch 4/1000
# 22/22 - 0s - loss: 0.6670 - accuracy: 0.6512 - 119ms/epoch - 5ms/step
# Epoch 5/1000
# 22/22 - 0s - loss: 0.6618 - accuracy: 0.6512 - 119ms/epoch - 5ms/step
# Epoch 6/1000
# 22/22 - 0s - loss: 0.6569 - accuracy: 0.6512 - 118ms/epoch - 5ms/step
# Epoch 7/1000
# 22/22 - 0s - loss: 0.6536 - accuracy: 0.6512 - 124ms/epoch - 6ms/step
# Epoch 8/1000
# 22/22 - 0s - loss: 0.6511 - accuracy: 0.6512 - 121ms/epoch - 5ms/step
# Epoch 9/1000
# 22/22 - 0s - loss: 0.6494 - accuracy: 0.6512 - 119ms/epoch - 5ms/step
# Epoch 10/1000
# 22/22 - 0s - loss: 0.6486 - accuracy: 0.6512 - 119ms/epoch - 5ms/step
# Epoch 11/1000
# 22/22 - 0s - loss: 0.6476 - accuracy: 0.6512 - 121ms/epoch - 6ms/step
# Epoch 12/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6512 - 121ms/epoch - 6ms/step
# Epoch 13/1000
# 22/22 - 0s - loss: 0.6472 - accuracy: 0.6512 - 137ms/epoch - 6ms/step
# Epoch 14/1000
# 22/22 - 0s - loss: 0.6470 - accuracy: 0.6512 - 118ms/epoch - 5ms/step
# Epoch 15/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 118ms/epoch - 5ms/step
# Epoch 16/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 119ms/epoch - 5ms/step
# Epoch 17/1000
# 22/22 - 0s - loss: 0.6469 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 18/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 19/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 20/1000
# 22/22 - 0s - loss: 0.6470 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 21/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 22/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 23/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 24/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 25/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 26/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 27/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 28/1000
# 22/22 - 0s - loss: 0.6469 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 29/1000
# 22/22 - 0s - loss: 0.6469 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 30/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 31/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 32/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 33/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 34/1000
# 22/22 - 0s - loss: 0.6469 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 35/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 120ms/epoch - 5ms/step
# Epoch 36/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 118ms/epoch - 5ms/step
# Epoch 37/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 119ms/epoch - 5ms/step
# Epoch 38/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 122ms/epoch - 6ms/step
# Epoch 39/1000
# 22/22 - 0s - loss: 0.6469 - accuracy: 0.6512 - 129ms/epoch - 6ms/step
# Epoch 40/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 41/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 42/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 43/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 44/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 45/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 46/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 47/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 134ms/epoch - 6ms/step
# Epoch 48/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 49/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 50/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 51/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 52/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 53/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 54/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 55/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 56/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 57/1000
# 22/22 - 0s - loss: 0.6470 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 58/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 59/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 60/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 61/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 62/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 63/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 64/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 65/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 66/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 67/1000
# 22/22 - 0s - loss: 0.6471 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 68/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 69/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 119ms/epoch - 5ms/step
# Epoch 70/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 71/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 72/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 73/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 74/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 75/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 123ms/epoch - 6ms/step
# Epoch 76/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 77/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 78/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 79/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 80/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 81/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 82/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 83/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 84/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 85/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 86/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 87/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 134ms/epoch - 6ms/step
# Epoch 88/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 89/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 90/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 91/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 92/1000
# 22/22 - 0s - loss: 0.6469 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 93/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 94/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 95/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 96/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 97/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 98/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 99/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 100/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 101/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 102/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 103/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 104/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 105/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 106/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 107/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 108/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 109/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 122ms/epoch - 6ms/step
# Epoch 110/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 119ms/epoch - 5ms/step
# Epoch 111/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 112/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 113/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 114/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 115/1000
# 22/22 - 0s - loss: 0.6471 - accuracy: 0.6512 - 133ms/epoch - 6ms/step
# Epoch 116/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 117/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 118/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 118: early stopping
# accuracy: 64.94%
# Epoch 1/1000
# 22/22 - 0s - loss: 0.6918 - accuracy: 0.6512 - 409ms/epoch - 19ms/step
# Epoch 2/1000
# 22/22 - 0s - loss: 0.6890 - accuracy: 0.6512 - 119ms/epoch - 5ms/step
# Epoch 3/1000
# 22/22 - 0s - loss: 0.6864 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 4/1000
# 22/22 - 0s - loss: 0.6838 - accuracy: 0.6512 - 119ms/epoch - 5ms/step
# Epoch 5/1000
# 22/22 - 0s - loss: 0.6814 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 6/1000
# 22/22 - 0s - loss: 0.6791 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 7/1000
# 22/22 - 0s - loss: 0.6769 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 8/1000
# 22/22 - 0s - loss: 0.6748 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 9/1000
# 22/22 - 0s - loss: 0.6728 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 10/1000
# 22/22 - 0s - loss: 0.6710 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 11/1000
# 22/22 - 0s - loss: 0.6693 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 12/1000
# 22/22 - 0s - loss: 0.6676 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 13/1000
# 22/22 - 0s - loss: 0.6661 - accuracy: 0.6512 - 139ms/epoch - 6ms/step
# Epoch 14/1000
# 22/22 - 0s - loss: 0.6648 - accuracy: 0.6512 - 118ms/epoch - 5ms/step
# Epoch 15/1000
# 22/22 - 0s - loss: 0.6634 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 16/1000
# 22/22 - 0s - loss: 0.6622 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 17/1000
# 22/22 - 0s - loss: 0.6611 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 18/1000
# 22/22 - 0s - loss: 0.6599 - accuracy: 0.6512 - 140ms/epoch - 6ms/step
# Epoch 19/1000
# 22/22 - 0s - loss: 0.6589 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 20/1000
# 22/22 - 0s - loss: 0.6581 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 21/1000
# 22/22 - 0s - loss: 0.6573 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 22/1000
# 22/22 - 0s - loss: 0.6563 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 23/1000
# 22/22 - 0s - loss: 0.6556 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 24/1000
# 22/22 - 0s - loss: 0.6549 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 25/1000
# 22/22 - 0s - loss: 0.6542 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 26/1000
# 22/22 - 0s - loss: 0.6536 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 27/1000
# 22/22 - 0s - loss: 0.6531 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 28/1000
# 22/22 - 0s - loss: 0.6526 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 29/1000
# 22/22 - 0s - loss: 0.6520 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 30/1000
# 22/22 - 0s - loss: 0.6516 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 31/1000
# 22/22 - 0s - loss: 0.6512 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 32/1000
# 22/22 - 0s - loss: 0.6508 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 33/1000
# 22/22 - 0s - loss: 0.6505 - accuracy: 0.6512 - 134ms/epoch - 6ms/step
# Epoch 34/1000
# 22/22 - 0s - loss: 0.6502 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 35/1000
# 22/22 - 0s - loss: 0.6499 - accuracy: 0.6512 - 123ms/epoch - 6ms/step
# Epoch 36/1000
# 22/22 - 0s - loss: 0.6495 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 37/1000
# 22/22 - 0s - loss: 0.6493 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 38/1000
# 22/22 - 0s - loss: 0.6490 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 39/1000
# 22/22 - 0s - loss: 0.6488 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 40/1000
# 22/22 - 0s - loss: 0.6487 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 41/1000
# 22/22 - 0s - loss: 0.6485 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 42/1000
# 22/22 - 0s - loss: 0.6483 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 43/1000
# 22/22 - 0s - loss: 0.6482 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 44/1000
# 22/22 - 0s - loss: 0.6480 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 45/1000
# 22/22 - 0s - loss: 0.6479 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 46/1000
# 22/22 - 0s - loss: 0.6478 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 47/1000
# 22/22 - 0s - loss: 0.6477 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 48/1000
# 22/22 - 0s - loss: 0.6476 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 49/1000
# 22/22 - 0s - loss: 0.6475 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 50/1000
# 22/22 - 0s - loss: 0.6475 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 51/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 52/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 53/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 54/1000
# 22/22 - 0s - loss: 0.6472 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 55/1000
# 22/22 - 0s - loss: 0.6471 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 56/1000
# 22/22 - 0s - loss: 0.6471 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 57/1000
# 22/22 - 0s - loss: 0.6471 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 58/1000
# 22/22 - 0s - loss: 0.6470 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 59/1000
# 22/22 - 0s - loss: 0.6470 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 60/1000
# 22/22 - 0s - loss: 0.6470 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 61/1000
# 22/22 - 0s - loss: 0.6469 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 62/1000
# 22/22 - 0s - loss: 0.6469 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 63/1000
# 22/22 - 0s - loss: 0.6469 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 64/1000
# 22/22 - 0s - loss: 0.6469 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 65/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 66/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 67/1000
# 22/22 - 0s - loss: 0.6469 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 68/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 69/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 134ms/epoch - 6ms/step
# Epoch 70/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 71/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 72/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 73/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 74/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 75/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 76/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 77/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 119ms/epoch - 5ms/step
# Epoch 78/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 79/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 80/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 81/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 82/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 83/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 84/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 85/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 86/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 87/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 88/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 89/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 90/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 91/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 92/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 93/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 94/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 95/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 96/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 97/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 118ms/epoch - 5ms/step
# Epoch 98/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 99/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 100/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 101/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 102/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 103/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 104/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 105/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 106/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 107/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 108/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 147ms/epoch - 7ms/step
# Epoch 109/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 110/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 111/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 120ms/epoch - 5ms/step
# Epoch 112/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 121ms/epoch - 6ms/step
# Epoch 113/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 114/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 115/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 116/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 117/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 118/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 119/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 120/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 121/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 122/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 122ms/epoch - 6ms/step
# Epoch 123/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 124/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 125/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 126/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 119ms/epoch - 5ms/step
# Epoch 127/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 119ms/epoch - 5ms/step
# Epoch 128/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 129/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 130/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 124ms/epoch - 6ms/step
# Epoch 131/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 123ms/epoch - 6ms/step
# Epoch 132/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 133/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 134/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 153ms/epoch - 7ms/step
# Epoch 135/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 136/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 137/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 138/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 128ms/epoch - 6ms/step
# Epoch 139/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 140/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 121ms/epoch - 5ms/step
# Epoch 141/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 142/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 118ms/epoch - 5ms/step
# Epoch 143/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 118ms/epoch - 5ms/step
# Epoch 144/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 145/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 146/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 147/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 148/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 122ms/epoch - 6ms/step
# Epoch 149/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 122ms/epoch - 6ms/step
# Epoch 150/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 135ms/epoch - 6ms/step
# Epoch 151/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 152/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 120ms/epoch - 5ms/step
# Epoch 153/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 142ms/epoch - 6ms/step
# Epoch 154/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 155/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 127ms/epoch - 6ms/step
# Epoch 156/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 157/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 158/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 123ms/epoch - 6ms/step
# Epoch 159/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 121ms/epoch - 6ms/step
# Epoch 160/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 161/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 162/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 163/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 158ms/epoch - 7ms/step
# Epoch 164/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 165/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 166/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 167/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 168/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 169/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 170/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 171/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 172/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 173/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 174/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 175/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 176/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 177/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 178/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 179/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 180/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 181/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 182/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 183/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 184/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 185/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 186/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 187/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 188/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 189/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 190/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 191/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 192/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 193/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 131ms/epoch - 6ms/step
# Epoch 194/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 195/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 196/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 197/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 198/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 199/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 200/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 201/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 202/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 203/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 204/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 205/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 206/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 207/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 208/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 209/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 210/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 211/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 212/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 213/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 214/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 110ms/epoch - 5ms/step
# Epoch 215/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 110ms/epoch - 5ms/step
# Epoch 216/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 217/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 218/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 219/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 118ms/epoch - 5ms/step
# Epoch 220/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 122ms/epoch - 6ms/step
# Epoch 221/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 222/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 136ms/epoch - 6ms/step
# Epoch 223/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 224/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 225/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 226/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 227/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 228/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 229/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 230/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 231/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 232/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 233/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 234/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 235/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 236/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 237/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 238/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 239/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 240/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 241/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 242/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 243/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 244/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 245/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 246/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 247/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 248/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 249/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 250/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 251/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 252/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 253/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 119ms/epoch - 5ms/step
# Epoch 254/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 255/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 256/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 257/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 258/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 259/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 124ms/epoch - 6ms/step
# Epoch 260/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 261/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 118ms/epoch - 5ms/step
# Epoch 262/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 263/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 264/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 265/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 266/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 267/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 268/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 269/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 270/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 271/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 272/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 273/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 274/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 275/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 276/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 277/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 278/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 279/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 280/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 281/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 125ms/epoch - 6ms/step
# Epoch 282/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 130ms/epoch - 6ms/step
# Epoch 283/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 284/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 285/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 286/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 287/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 288/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 289/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 290/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 291/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 292/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 293/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 140ms/epoch - 6ms/step
# Epoch 294/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 295/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 296/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 123ms/epoch - 6ms/step
# Epoch 297/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 298/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 132ms/epoch - 6ms/step
# Epoch 299/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 300/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 301/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 302/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 303/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 304/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 305/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 306/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 307/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 308/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 309/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 310/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 311/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 312/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 313/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 314/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 315/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 316/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 317/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 318/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 319/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 320/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 321/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 322/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 323/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 324/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 325/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 326/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 327/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 328/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 329/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 330/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 331/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 332/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 333/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 334/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 335/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 336/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 337/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 338/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 339/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 133ms/epoch - 6ms/step
# Epoch 340/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 341/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 342/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 343/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 344/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 345/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 346/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 347/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 348/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 129ms/epoch - 6ms/step
# Epoch 349/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 350/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 351/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 352/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 353/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 119ms/epoch - 5ms/step
# Epoch 354/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 126ms/epoch - 6ms/step
# Epoch 355/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 356/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 357/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 358/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 359/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 119ms/epoch - 5ms/step
# Epoch 360/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 361/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 362/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 363/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 124ms/epoch - 6ms/step
# Epoch 364/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 132ms/epoch - 6ms/step
# Epoch 365/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 366/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 367/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 368/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 121ms/epoch - 5ms/step
# Epoch 369/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 370/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 371/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 372/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 373/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 374/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 375/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 376/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 377/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 378/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 379/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 380/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 381/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 382/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 383/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 112ms/epoch - 5ms/step
# Epoch 384/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 385/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 386/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 111ms/epoch - 5ms/step
# Epoch 387/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 139ms/epoch - 6ms/step
# Epoch 388/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 121ms/epoch - 6ms/step
# Epoch 389/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 390/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 391/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 392/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 126ms/epoch - 6ms/step
# Epoch 393/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 123ms/epoch - 6ms/step
# Epoch 394/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 118ms/epoch - 5ms/step
# Epoch 395/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 396/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 113ms/epoch - 5ms/step
# Epoch 397/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 126ms/epoch - 6ms/step
# Epoch 397: early stopping
# accuracy: 64.94%
# Epoch 1/1000
# 22/22 - 0s - loss: 0.6857 - accuracy: 0.6512 - 420ms/epoch - 19ms/step
# Epoch 2/1000
# 22/22 - 0s - loss: 0.6732 - accuracy: 0.6512 - 121ms/epoch - 6ms/step
# Epoch 3/1000
# 22/22 - 0s - loss: 0.6638 - accuracy: 0.6512 - 118ms/epoch - 5ms/step
# Epoch 4/1000
# 22/22 - 0s - loss: 0.6566 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 5/1000
# 22/22 - 0s - loss: 0.6529 - accuracy: 0.6512 - 123ms/epoch - 6ms/step
# Epoch 6/1000
# 22/22 - 0s - loss: 0.6497 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 7/1000
# 22/22 - 0s - loss: 0.6482 - accuracy: 0.6512 - 127ms/epoch - 6ms/step
# Epoch 8/1000
# 22/22 - 0s - loss: 0.6475 - accuracy: 0.6512 - 136ms/epoch - 6ms/step
# Epoch 9/1000
# 22/22 - 0s - loss: 0.6470 - accuracy: 0.6512 - 120ms/epoch - 5ms/step
# Epoch 10/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 119ms/epoch - 5ms/step
# Epoch 11/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 12/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 13/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 14/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 15/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 16/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 17/1000
# 22/22 - 0s - loss: 0.6469 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 18/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 19/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 20/1000
# 22/22 - 0s - loss: 0.6469 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 21/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 22/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 118ms/epoch - 5ms/step
# Epoch 23/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 24/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 25/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 26/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 27/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 28/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 29/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 30/1000
# 22/22 - 0s - loss: 0.6469 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 31/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 32/1000
# 22/22 - 0s - loss: 0.6469 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 33/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 114ms/epoch - 5ms/step
# Epoch 34/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 35/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 36/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 37/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 38/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 39/1000
# 22/22 - 0s - loss: 0.6469 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 40/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 134ms/epoch - 6ms/step
# Epoch 41/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 42/1000
# 22/22 - 0s - loss: 0.6470 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 43/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 121ms/epoch - 6ms/step
# Epoch 44/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 45/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 116ms/epoch - 5ms/step
# Epoch 46/1000
# 22/22 - 0s - loss: 0.6467 - accuracy: 0.6512 - 115ms/epoch - 5ms/step
# Epoch 47/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 117ms/epoch - 5ms/step
# Epoch 48/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 120ms/epoch - 5ms/step
# Epoch 49/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 119ms/epoch - 5ms/step
# Epoch 50/1000
# 22/22 - 0s - loss: 0.6468 - accuracy: 0.6512 - 118ms/epoch - 5ms/step
# Epoch 51/1000
# 22/22 - 0s - loss: 0.6469 - accuracy: 0.6512 - 120ms/epoch - 5ms/step
# Epoch 52/1000
# ...
# Epoch 111/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 237ms/epoch - 11ms/step
# Epoch 112/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 311ms/epoch - 14ms/step
# Epoch 113/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 265ms/epoch - 12ms/step
# Epoch 114/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 242ms/epoch - 11ms/step
# Epoch 115/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 246ms/epoch - 11ms/step
# Epoch 116/1000
# 22/22 - 0s - loss: 0.6475 - accuracy: 0.6503 - 204ms/epoch - 9ms/step
# Epoch 117/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 202ms/epoch - 9ms/step
# Epoch 118/1000
# 22/22 - 0s - loss: 0.6478 - accuracy: 0.6503 - 204ms/epoch - 9ms/step
# Epoch 119/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 202ms/epoch - 9ms/step
# Epoch 120/1000
# 22/22 - 0s - loss: 0.6475 - accuracy: 0.6503 - 200ms/epoch - 9ms/step
# Epoch 121/1000
# 22/22 - 0s - loss: 0.6475 - accuracy: 0.6503 - 181ms/epoch - 8ms/step
# Epoch 122/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 181ms/epoch - 8ms/step
# Epoch 123/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 185ms/epoch - 8ms/step
# Epoch 124/1000
# 22/22 - 0s - loss: 0.6477 - accuracy: 0.6503 - 184ms/epoch - 8ms/step
# Epoch 125/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 188ms/epoch - 9ms/step
# Epoch 126/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 189ms/epoch - 9ms/step
# Epoch 127/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 183ms/epoch - 8ms/step
# Epoch 128/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 183ms/epoch - 8ms/step
# Epoch 129/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 185ms/epoch - 8ms/step
# Epoch 130/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 227ms/epoch - 10ms/step
# Epoch 131/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 204ms/epoch - 9ms/step
# Epoch 132/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 203ms/epoch - 9ms/step
# Epoch 133/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 203ms/epoch - 9ms/step
# Epoch 134/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 201ms/epoch - 9ms/step
# Epoch 135/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 189ms/epoch - 9ms/step
# Epoch 136/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 183ms/epoch - 8ms/step
# Epoch 137/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 182ms/epoch - 8ms/step
# Epoch 138/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 183ms/epoch - 8ms/step
# Epoch 139/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 184ms/epoch - 8ms/step
# Epoch 140/1000
# 22/22 - 0s - loss: 0.6475 - accuracy: 0.6503 - 184ms/epoch - 8ms/step
# Epoch 141/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 191ms/epoch - 9ms/step
# Epoch 142/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 182ms/epoch - 8ms/step
# Epoch 143/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 182ms/epoch - 8ms/step
# Epoch 144/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 185ms/epoch - 8ms/step
# Epoch 145/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 184ms/epoch - 8ms/step
# Epoch 146/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 187ms/epoch - 9ms/step
# Epoch 147/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 183ms/epoch - 8ms/step
# Epoch 148/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 222ms/epoch - 10ms/step
# Epoch 149/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 201ms/epoch - 9ms/step
# Epoch 150/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 201ms/epoch - 9ms/step
# Epoch 151/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 203ms/epoch - 9ms/step
# Epoch 152/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 190ms/epoch - 9ms/step
# Epoch 153/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 176ms/epoch - 8ms/step
# Epoch 154/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 181ms/epoch - 8ms/step
# Epoch 155/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 179ms/epoch - 8ms/step
# Epoch 156/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 188ms/epoch - 9ms/step
# Epoch 156: early stopping
# accuracy: 65.79%
# Epoch 1/1000
# 22/22 - 1s - loss: 0.6904 - accuracy: 0.6301 - 851ms/epoch - 39ms/step
# Epoch 2/1000
# 22/22 - 0s - loss: 0.6842 - accuracy: 0.6503 - 180ms/epoch - 8ms/step
# Epoch 3/1000
# 22/22 - 0s - loss: 0.6779 - accuracy: 0.6503 - 182ms/epoch - 8ms/step
# Epoch 4/1000
# 22/22 - 0s - loss: 0.6729 - accuracy: 0.6503 - 182ms/epoch - 8ms/step
# Epoch 5/1000
# 22/22 - 0s - loss: 0.6680 - accuracy: 0.6503 - 203ms/epoch - 9ms/step
# Epoch 6/1000
# 22/22 - 0s - loss: 0.6638 - accuracy: 0.6503 - 184ms/epoch - 8ms/step
# Epoch 7/1000
# 22/22 - 0s - loss: 0.6600 - accuracy: 0.6503 - 179ms/epoch - 8ms/step
# Epoch 8/1000
# 22/22 - 0s - loss: 0.6570 - accuracy: 0.6503 - 184ms/epoch - 8ms/step
# Epoch 9/1000
# 22/22 - 0s - loss: 0.6544 - accuracy: 0.6503 - 178ms/epoch - 8ms/step
# Epoch 10/1000
# 22/22 - 0s - loss: 0.6526 - accuracy: 0.6503 - 177ms/epoch - 8ms/step
# Epoch 11/1000
# 22/22 - 0s - loss: 0.6511 - accuracy: 0.6503 - 183ms/epoch - 8ms/step
# Epoch 12/1000
# 22/22 - 0s - loss: 0.6498 - accuracy: 0.6503 - 182ms/epoch - 8ms/step
# Epoch 13/1000
# 22/22 - 0s - loss: 0.6490 - accuracy: 0.6503 - 194ms/epoch - 9ms/step
# Epoch 14/1000
# 22/22 - 0s - loss: 0.6486 - accuracy: 0.6503 - 187ms/epoch - 8ms/step
# Epoch 15/1000
# 22/22 - 0s - loss: 0.6480 - accuracy: 0.6503 - 212ms/epoch - 10ms/step
# Epoch 16/1000
# 22/22 - 0s - loss: 0.6479 - accuracy: 0.6503 - 212ms/epoch - 10ms/step
# Epoch 17/1000
# 22/22 - 0s - loss: 0.6478 - accuracy: 0.6503 - 207ms/epoch - 9ms/step
# Epoch 18/1000
# 22/22 - 0s - loss: 0.6476 - accuracy: 0.6503 - 209ms/epoch - 9ms/step
# Epoch 19/1000
# 22/22 - 0s - loss: 0.6475 - accuracy: 0.6503 - 206ms/epoch - 9ms/step
# Epoch 20/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 203ms/epoch - 9ms/step
# Epoch 21/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 210ms/epoch - 10ms/step
# Epoch 22/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 209ms/epoch - 10ms/step
# Epoch 23/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 211ms/epoch - 10ms/step
# Epoch 24/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 229ms/epoch - 10ms/step
# Epoch 25/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 284ms/epoch - 13ms/step
# Epoch 26/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 239ms/epoch - 11ms/step
# Epoch 27/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 239ms/epoch - 11ms/step
# Epoch 28/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 249ms/epoch - 11ms/step
# Epoch 29/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 300ms/epoch - 14ms/step
# Epoch 30/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 379ms/epoch - 17ms/step
# Epoch 31/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 285ms/epoch - 13ms/step
# Epoch 32/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 281ms/epoch - 13ms/step
# Epoch 33/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 405ms/epoch - 18ms/step
# Epoch 34/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 391ms/epoch - 18ms/step
# Epoch 35/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 357ms/epoch - 16ms/step
# Epoch 36/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 362ms/epoch - 16ms/step
# Epoch 37/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 285ms/epoch - 13ms/step
# Epoch 38/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 304ms/epoch - 14ms/step
# Epoch 39/1000
# 22/22 - 0s - loss: 0.6475 - accuracy: 0.6503 - 259ms/epoch - 12ms/step
# Epoch 40/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 260ms/epoch - 12ms/step
# Epoch 41/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 258ms/epoch - 12ms/step
# Epoch 42/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 246ms/epoch - 11ms/step
# Epoch 43/1000
# 22/22 - 0s - loss: 0.6476 - accuracy: 0.6503 - 248ms/epoch - 11ms/step
# Epoch 44/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 242ms/epoch - 11ms/step
# Epoch 45/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 249ms/epoch - 11ms/step
# Epoch 46/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 247ms/epoch - 11ms/step
# Epoch 47/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 245ms/epoch - 11ms/step
# Epoch 48/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 247ms/epoch - 11ms/step
# Epoch 49/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 250ms/epoch - 11ms/step
# Epoch 50/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 247ms/epoch - 11ms/step
# Epoch 51/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 239ms/epoch - 11ms/step
# Epoch 52/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 250ms/epoch - 11ms/step
# Epoch 53/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 249ms/epoch - 11ms/step
# Epoch 54/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 228ms/epoch - 10ms/step
# Epoch 55/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 231ms/epoch - 11ms/step
# Epoch 56/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 229ms/epoch - 10ms/step
# Epoch 57/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 293ms/epoch - 13ms/step
# Epoch 58/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 302ms/epoch - 14ms/step
# Epoch 59/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 315ms/epoch - 14ms/step
# Epoch 60/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 312ms/epoch - 14ms/step
# Epoch 61/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 302ms/epoch - 14ms/step
# Epoch 62/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 270ms/epoch - 12ms/step
# Epoch 63/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 248ms/epoch - 11ms/step
# Epoch 64/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 243ms/epoch - 11ms/step
# Epoch 65/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 252ms/epoch - 11ms/step
# Epoch 66/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 236ms/epoch - 11ms/step
# Epoch 67/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 213ms/epoch - 10ms/step
# Epoch 68/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 273ms/epoch - 12ms/step
# Epoch 69/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 241ms/epoch - 11ms/step
# Epoch 70/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 247ms/epoch - 11ms/step
# Epoch 71/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 297ms/epoch - 13ms/step
# Epoch 72/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 276ms/epoch - 13ms/step
# Epoch 73/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 243ms/epoch - 11ms/step
# Epoch 74/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 243ms/epoch - 11ms/step
# Epoch 75/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 251ms/epoch - 11ms/step
# Epoch 76/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 283ms/epoch - 13ms/step
# Epoch 77/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 294ms/epoch - 13ms/step
# Epoch 78/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 260ms/epoch - 12ms/step
# Epoch 79/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 250ms/epoch - 11ms/step
# Epoch 80/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 220ms/epoch - 10ms/step
# Epoch 81/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 206ms/epoch - 9ms/step
# Epoch 82/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 205ms/epoch - 9ms/step
# Epoch 83/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 211ms/epoch - 10ms/step
# Epoch 84/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 210ms/epoch - 10ms/step
# Epoch 85/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 209ms/epoch - 9ms/step
# Epoch 86/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 206ms/epoch - 9ms/step
# Epoch 87/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 207ms/epoch - 9ms/step
# Epoch 88/1000
# 22/22 - 0s - loss: 0.6474 - accuracy: 0.6503 - 209ms/epoch - 9ms/step
# Epoch 89/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 208ms/epoch - 9ms/step
# Epoch 90/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 245ms/epoch - 11ms/step
# Epoch 91/1000
# 22/22 - 0s - loss: 0.6473 - accuracy: 0.6503 - 223ms/epoch - 10ms/step
# Epoch 92/1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/anvu/Workspace/Master/DeepLearningFoundation/Diabetes-DeepLearning-KNNImpute.ipynb Cell 12 line 8
#       <a href='vscode-notebook-cell:/Users/anvu/Workspace/Master/DeepLearningFoundation/Diabetes-DeepLearning-KNNImpute.ipynb#X30sZmlsZQ%3D%3D?line=5'>6</a> model = create_model()
#       <a href='vscode-notebook-cell:/Users/anvu/Workspace/Master/DeepLearningFoundation/Diabetes-DeepLearning-KNNImpute.ipynb#X30sZmlsZQ%3D%3D?line=6'>7</a> earlystoping = EarlyStopping(monitor = 'loss', mode = 'min', verbose = 1, patience = 100)
# ----> <a href='vscode-notebook-cell:/Users/anvu/Workspace/Master/DeepLearningFoundation/Diabetes-DeepLearning-KNNImpute.ipynb#X30sZmlsZQ%3D%3D?line=7'>8</a> model.fit(X.iloc[train], y.iloc[train], epochs = 1000, batch_size = 32, verbose = 2, callbacks=[earlystoping])
#       <a href='vscode-notebook-cell:/Users/anvu/Workspace/Master/DeepLearningFoundation/Diabetes-DeepLearning-KNNImpute.ipynb#X30sZmlsZQ%3D%3D?line=8'>9</a> scores = model.evaluate(X.iloc[test], y.iloc[test], verbose = 0)
#      <a href='vscode-notebook-cell:/Users/anvu/Workspace/Master/DeepLearningFoundation/Diabetes-DeepLearning-KNNImpute.ipynb#X30sZmlsZQ%3D%3D?line=9'>10</a> print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/keras/engine/training.py:1676, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1674 callbacks.on_epoch_begin(epoch)
#    1675 with data_handler.catch_stop_iteration():
# -> 1676     for step in data_handler.steps():
#    1677         with tf.profiler.experimental.Trace(
#    1678             "train",
#    1679             epoch_num=epoch,
#    (...)
#    1682             _r=1,
#    1683         ):
#    1684             callbacks.on_train_batch_begin(step)
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/keras/engine/data_adapter.py:1375, in DataHandler.steps(self)
#    1373 if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1374     break
# -> 1375 original_spe = self._steps_per_execution.numpy().item()
#    1376 can_run_full_execution = (
#    1377     original_spe == 1
#    1378     or self._inferred_steps is None
#    1379     or self._inferred_steps - self._current_step >= original_spe
#    1380 )
#    1382 if can_run_full_execution:
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/tensorflow/python/ops/resource_variable_ops.py:647, in BaseResourceVariable.numpy(self)
#     645 def numpy(self):
#     646   if context.executing_eagerly():
# --> 647     return self.read_value().numpy()
#     648   raise NotImplementedError(
#     649       "numpy() is only available when eager execution is enabled.")
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:1160, in _EagerTensorBase.numpy(self)
#    1137 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1138
#    1139 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1157     NumPy dtype.
#    1158 """
#    1159 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1160 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1161 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:1126, in _EagerTensorBase._numpy(self)
#    1124 def _numpy(self):
#    1125   try:
# -> 1126     return self._numpy_internal()
#    1127   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1128     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:

# %%
# using library and do k-fold cross validation
