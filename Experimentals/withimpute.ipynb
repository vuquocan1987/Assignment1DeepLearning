# %%
# load the "diabetes.csv" file and clean data to prepare for deep learning model
# 1. load data
# 2. clean data
# 3. impute missing values
# 4. save data

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
import warnings
import tensorflow as tf
warnings.filterwarnings('ignore')

# load data
df = pd.read_csv('diabetes.csv')
print(df.shape)
df.head()
# Out:
# (768, 9)
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 0            6      148             72             35        0  33.6  \
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.sum()
# Out:
# Pregnancies                  2953.000
# Glucose                     92847.000
# BloodPressure               53073.000
# SkinThickness               15772.000
# Insulin                     61286.000
# BMI                         24570.300
# DiabetesPedigreeFunction      362.401
# Age                         25529.000
# Outcome                       268.000
# dtype: float64

# %%
# fill the 0 in glucose, blood pressure, skin thickness, insulin, bmi with NaN
df[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']] = df[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']].replace(0,np.NaN)
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 0            6    148.0           72.0           35.0      NaN  33.6  \
# 1            1     85.0           66.0           29.0      NaN  26.6
# 2            8    183.0           64.0            NaN      NaN  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
df.groupby('Outcome')["BloodPressure"].transform('median')
# Out:
# 0      74.5
# 1      70.0
# 2      74.5
# 3      70.0
# 4      74.5
#        ...
# 763    70.0
# 764    70.0
# 765    70.0
# 766    74.5
# 767    70.0
# Name: BloodPressure, Length: 768, dtype: float64

# %%
# copy the dataframe
df_filled = df.copy(deep=True)

# %%
df["BloodPressure"].sum()
# Out:
# 53073.0

# %%
# calculate the median value for each column split by the outcome, and fill the NaN with the median value of the corresponding outcome for df_filled dataframe
df_filled['Glucose'].fillna(df_filled.groupby('Outcome')['Glucose'].transform('median'), inplace=True)
# df_filled['BloodPressure'].fillna(df_filled.groupby('Outcome')['BloodPressure'].transform('median'), inplace=True)
df_filled['SkinThickness'].fillna(df_filled.groupby('Outcome')['SkinThickness'].transform('median'), inplace=True)
df_filled['Insulin'].fillna(df_filled.groupby('Outcome')['Insulin'].transform('median'), inplace=True)
df_filled['BMI'].fillna(df_filled.groupby('Outcome')['BMI'].transform('median'), inplace=True)

# %%
# calculate the median value for each column split by the outcome, and fill the NaN with the median value of the corresponding outcome
df['Glucose'].fillna(df.groupby('Outcome')['Glucose'].transform('median'), inplace=True)
df['BloodPressure'].fillna(df.groupby('Outcome')['BloodPressure'].transform('median'), inplace=True)
df['SkinThickness'].fillna(df.groupby('Outcome')['SkinThickness'].transform('median'), inplace=True)
df['Insulin'].fillna(df.groupby('Outcome')['Insulin'].transform('median'), inplace=True)
df['BMI'].fillna(df.groupby('Outcome')['BMI'].transform('median'), inplace=True)

# %%
df["BloodPressure"].sum()
# Out:
# 55595.0

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.sum()
# Out:
# Pregnancies                   2953.000
# Glucose                      93448.000
# BloodPressure                55595.000
# SkinThickness                22341.000
# Insulin                     108867.000
# BMI                          24909.800
# DiabetesPedigreeFunction       362.401
# Age                          25529.000
# Outcome                        268.000
# dtype: float64

# %%
# scale the data using min-max scaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_scaled = scaler.fit_transform(df_filled.iloc[:,:-1])
df_scaled = pd.DataFrame(df_scaled, columns = df.columns[:-1])
df_scaled['Outcome'] = df['Outcome']
df_scaled.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI
# 0     0.352941  0.670968       0.489796       0.304348  0.186899  0.314928  \
# 1     0.058824  0.264516       0.428571       0.239130  0.106370  0.171779
# 2     0.470588  0.896774       0.408163       0.271739  0.186899  0.104294
# 3     0.058824  0.290323       0.428571       0.173913  0.096154  0.202454
# 4     0.000000  0.600000       0.163265       0.304348  0.185096  0.509202
#
#    DiabetesPedigreeFunction       Age  Outcome
# 0                  0.234415  0.483333        1
# 1                  0.116567  0.166667        0
# 2                  0.253629  0.183333        1
# 3                  0.038002  0.000000        0
# 4                  0.943638  0.200000        1

# %%
df_scaled.sum()
# Out:
# Pregnancies                 173.705882
# Glucose                     384.877419
# BloodPressure               362.051020
# SkinThickness               184.402174
# Insulin                     117.926683
# BMI                         223.562372
# DiabetesPedigreeFunction    129.161827
# Age                         156.683333
# Outcome                     268.000000
# dtype: float64

# %%
# create X and Y
X = df_scaled.drop('Outcome', axis = 1)
Y = df_scaled['Outcome']
X = np.array(X)
Y = np.array(Y)

# %%
# train test split 1 1 8
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.1, stratify = Y, random_state = 2)
X_train, X_val, Y_train, Y_val = train_test_split(X_train,Y_train, test_size = 0.1, stratify = Y_train, random_state = 2)

# %%
# function to create model
from keras.models import Sequential
from keras.layers import Dense
def create_model():
    model = Sequential([
        Dense(20, activation = 'relu', input_shape = (8,)),
        Dense(5, activation = 'relu'),
        Dense(1, activation = 'sigmoid')
    ])
    optimizer = tf.keras.optimizers.legacy.RMSprop(lr=0.001)
    model.compile(loss = 'binary_crossentropy', optimizer = optimizer, metrics = ['accuracy'])
    return model

# %%
# train the model
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.1, stratify = Y, random_state = 2)
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    verbose=1,
    patience=100,
    mode='min',
    restore_best_weights=True)
model = create_model()
model.fit(X_train,Y_train, validation_split=.2, epochs = 1000, verbose = 2)
# Out:
# Epoch 1/1000
# 18/18 - 1s - loss: 0.6766 - accuracy: 0.6504 - val_loss: 0.6715 - val_accuracy: 0.6259 - 1s/epoch - 66ms/step
# Epoch 2/1000
# 18/18 - 0s - loss: 0.6592 - accuracy: 0.6576 - val_loss: 0.6644 - val_accuracy: 0.6259 - 155ms/epoch - 9ms/step
# Epoch 3/1000
# 18/18 - 0s - loss: 0.6512 - accuracy: 0.6576 - val_loss: 0.6622 - val_accuracy: 0.6259 - 156ms/epoch - 9ms/step
# Epoch 4/1000
# 18/18 - 0s - loss: 0.6472 - accuracy: 0.6576 - val_loss: 0.6611 - val_accuracy: 0.6259 - 134ms/epoch - 7ms/step
# Epoch 5/1000
# 18/18 - 0s - loss: 0.6448 - accuracy: 0.6576 - val_loss: 0.6612 - val_accuracy: 0.6259 - 135ms/epoch - 7ms/step
# Epoch 6/1000
# 18/18 - 0s - loss: 0.6441 - accuracy: 0.6576 - val_loss: 0.6615 - val_accuracy: 0.6259 - 126ms/epoch - 7ms/step
# Epoch 7/1000
# 18/18 - 0s - loss: 0.6435 - accuracy: 0.6576 - val_loss: 0.6617 - val_accuracy: 0.6259 - 145ms/epoch - 8ms/step
# Epoch 8/1000
# 18/18 - 0s - loss: 0.6433 - accuracy: 0.6576 - val_loss: 0.6623 - val_accuracy: 0.6259 - 158ms/epoch - 9ms/step
# Epoch 9/1000
# 18/18 - 0s - loss: 0.6432 - accuracy: 0.6576 - val_loss: 0.6626 - val_accuracy: 0.6259 - 130ms/epoch - 7ms/step
# Epoch 10/1000
# 18/18 - 0s - loss: 0.6431 - accuracy: 0.6576 - val_loss: 0.6623 - val_accuracy: 0.6259 - 145ms/epoch - 8ms/step
# Epoch 11/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6622 - val_accuracy: 0.6259 - 133ms/epoch - 7ms/step
# Epoch 12/1000
# 18/18 - 0s - loss: 0.6432 - accuracy: 0.6576 - val_loss: 0.6627 - val_accuracy: 0.6259 - 132ms/epoch - 7ms/step
# Epoch 13/1000
# 18/18 - 0s - loss: 0.6431 - accuracy: 0.6576 - val_loss: 0.6632 - val_accuracy: 0.6259 - 127ms/epoch - 7ms/step
# Epoch 14/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6629 - val_accuracy: 0.6259 - 133ms/epoch - 7ms/step
# Epoch 15/1000
# 18/18 - 0s - loss: 0.6431 - accuracy: 0.6576 - val_loss: 0.6632 - val_accuracy: 0.6259 - 127ms/epoch - 7ms/step
# Epoch 16/1000
# 18/18 - 0s - loss: 0.6432 - accuracy: 0.6576 - val_loss: 0.6629 - val_accuracy: 0.6259 - 135ms/epoch - 8ms/step
# Epoch 17/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6633 - val_accuracy: 0.6259 - 125ms/epoch - 7ms/step
# Epoch 18/1000
# 18/18 - 0s - loss: 0.6432 - accuracy: 0.6576 - val_loss: 0.6628 - val_accuracy: 0.6259 - 126ms/epoch - 7ms/step
# Epoch 19/1000
# 18/18 - 0s - loss: 0.6428 - accuracy: 0.6576 - val_loss: 0.6628 - val_accuracy: 0.6259 - 136ms/epoch - 8ms/step
# Epoch 20/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6627 - val_accuracy: 0.6259 - 140ms/epoch - 8ms/step
# Epoch 21/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6626 - val_accuracy: 0.6259 - 133ms/epoch - 7ms/step
# Epoch 22/1000
# 18/18 - 0s - loss: 0.6431 - accuracy: 0.6576 - val_loss: 0.6624 - val_accuracy: 0.6259 - 196ms/epoch - 11ms/step
# Epoch 23/1000
# 18/18 - 0s - loss: 0.6431 - accuracy: 0.6576 - val_loss: 0.6623 - val_accuracy: 0.6259 - 128ms/epoch - 7ms/step
# Epoch 24/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6623 - val_accuracy: 0.6259 - 127ms/epoch - 7ms/step
# Epoch 25/1000
# 18/18 - 0s - loss: 0.6431 - accuracy: 0.6576 - val_loss: 0.6624 - val_accuracy: 0.6259 - 139ms/epoch - 8ms/step
# Epoch 26/1000
# 18/18 - 0s - loss: 0.6431 - accuracy: 0.6576 - val_loss: 0.6626 - val_accuracy: 0.6259 - 130ms/epoch - 7ms/step
# Epoch 27/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6623 - val_accuracy: 0.6259 - 123ms/epoch - 7ms/step
# Epoch 28/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6629 - val_accuracy: 0.6259 - 127ms/epoch - 7ms/step
# Epoch 29/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6630 - val_accuracy: 0.6259 - 124ms/epoch - 7ms/step
# Epoch 30/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6633 - val_accuracy: 0.6259 - 126ms/epoch - 7ms/step
# Epoch 31/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6633 - val_accuracy: 0.6259 - 125ms/epoch - 7ms/step
# Epoch 32/1000
# 18/18 - 0s - loss: 0.6432 - accuracy: 0.6576 - val_loss: 0.6639 - val_accuracy: 0.6259 - 126ms/epoch - 7ms/step
# Epoch 33/1000
# 18/18 - 0s - loss: 0.6428 - accuracy: 0.6576 - val_loss: 0.6633 - val_accuracy: 0.6259 - 124ms/epoch - 7ms/step
# Epoch 34/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6630 - val_accuracy: 0.6259 - 125ms/epoch - 7ms/step
# Epoch 35/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6633 - val_accuracy: 0.6259 - 191ms/epoch - 11ms/step
# Epoch 36/1000
# 18/18 - 0s - loss: 0.6431 - accuracy: 0.6576 - val_loss: 0.6628 - val_accuracy: 0.6259 - 130ms/epoch - 7ms/step
# Epoch 37/1000
# 18/18 - 0s - loss: 0.6427 - accuracy: 0.6576 - val_loss: 0.6639 - val_accuracy: 0.6259 - 136ms/epoch - 8ms/step
# Epoch 38/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6635 - val_accuracy: 0.6259 - 124ms/epoch - 7ms/step
# Epoch 39/1000
# 18/18 - 0s - loss: 0.6432 - accuracy: 0.6576 - val_loss: 0.6629 - val_accuracy: 0.6259 - 133ms/epoch - 7ms/step
# Epoch 40/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6634 - val_accuracy: 0.6259 - 124ms/epoch - 7ms/step
# Epoch 41/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6634 - val_accuracy: 0.6259 - 130ms/epoch - 7ms/step
# Epoch 42/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6631 - val_accuracy: 0.6259 - 137ms/epoch - 8ms/step
# Epoch 43/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6636 - val_accuracy: 0.6259 - 126ms/epoch - 7ms/step
# Epoch 44/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6629 - val_accuracy: 0.6259 - 125ms/epoch - 7ms/step
# Epoch 45/1000
# 18/18 - 0s - loss: 0.6428 - accuracy: 0.6576 - val_loss: 0.6632 - val_accuracy: 0.6259 - 124ms/epoch - 7ms/step
# Epoch 46/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6626 - val_accuracy: 0.6259 - 134ms/epoch - 7ms/step
# Epoch 47/1000
# 18/18 - 0s - loss: 0.6428 - accuracy: 0.6576 - val_loss: 0.6637 - val_accuracy: 0.6259 - 133ms/epoch - 7ms/step
# Epoch 48/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6639 - val_accuracy: 0.6259 - 125ms/epoch - 7ms/step
# Epoch 49/1000
# 18/18 - 0s - loss: 0.6428 - accuracy: 0.6576 - val_loss: 0.6628 - val_accuracy: 0.6259 - 128ms/epoch - 7ms/step
# Epoch 50/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6629 - val_accuracy: 0.6259 - 125ms/epoch - 7ms/step
# Epoch 51/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6634 - val_accuracy: 0.6259 - 126ms/epoch - 7ms/step
# Epoch 52/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6633 - val_accuracy: 0.6259 - 133ms/epoch - 7ms/step
# Epoch 53/1000
# 18/18 - 0s - loss: 0.6431 - accuracy: 0.6576 - val_loss: 0.6637 - val_accuracy: 0.6259 - 126ms/epoch - 7ms/step
# Epoch 54/1000
# 18/18 - 0s - loss: 0.6428 - accuracy: 0.6576 - val_loss: 0.6636 - val_accuracy: 0.6259 - 177ms/epoch - 10ms/step
# Epoch 55/1000
# 18/18 - 0s - loss: 0.6433 - accuracy: 0.6576 - val_loss: 0.6631 - val_accuracy: 0.6259 - 124ms/epoch - 7ms/step
# Epoch 56/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6638 - val_accuracy: 0.6259 - 127ms/epoch - 7ms/step
# Epoch 57/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6639 - val_accuracy: 0.6259 - 125ms/epoch - 7ms/step
# Epoch 58/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6631 - val_accuracy: 0.6259 - 128ms/epoch - 7ms/step
# Epoch 59/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6631 - val_accuracy: 0.6259 - 134ms/epoch - 7ms/step
# Epoch 60/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6625 - val_accuracy: 0.6259 - 140ms/epoch - 8ms/step
# Epoch 61/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6624 - val_accuracy: 0.6259 - 138ms/epoch - 8ms/step
# Epoch 62/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6626 - val_accuracy: 0.6259 - 135ms/epoch - 7ms/step
# Epoch 63/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6632 - val_accuracy: 0.6259 - 129ms/epoch - 7ms/step
# Epoch 64/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6634 - val_accuracy: 0.6259 - 129ms/epoch - 7ms/step
# Epoch 65/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6629 - val_accuracy: 0.6259 - 131ms/epoch - 7ms/step
# Epoch 66/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6629 - val_accuracy: 0.6259 - 131ms/epoch - 7ms/step
# Epoch 67/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6636 - val_accuracy: 0.6259 - 149ms/epoch - 8ms/step
# Epoch 68/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6639 - val_accuracy: 0.6259 - 174ms/epoch - 10ms/step
# Epoch 69/1000
# 18/18 - 0s - loss: 0.6431 - accuracy: 0.6576 - val_loss: 0.6641 - val_accuracy: 0.6259 - 131ms/epoch - 7ms/step
# Epoch 70/1000
# 18/18 - 0s - loss: 0.6431 - accuracy: 0.6576 - val_loss: 0.6637 - val_accuracy: 0.6259 - 131ms/epoch - 7ms/step
# Epoch 71/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6633 - val_accuracy: 0.6259 - 125ms/epoch - 7ms/step
# Epoch 72/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6629 - val_accuracy: 0.6259 - 127ms/epoch - 7ms/step
# Epoch 73/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6623 - val_accuracy: 0.6259 - 145ms/epoch - 8ms/step
# Epoch 74/1000
# 18/18 - 0s - loss: 0.6431 - accuracy: 0.6576 - val_loss: 0.6622 - val_accuracy: 0.6259 - 127ms/epoch - 7ms/step
# Epoch 75/1000
# 18/18 - 0s - loss: 0.6432 - accuracy: 0.6576 - val_loss: 0.6624 - val_accuracy: 0.6259 - 128ms/epoch - 7ms/step
# Epoch 76/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6627 - val_accuracy: 0.6259 - 185ms/epoch - 10ms/step
# Epoch 77/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6630 - val_accuracy: 0.6259 - 145ms/epoch - 8ms/step
# Epoch 78/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6636 - val_accuracy: 0.6259 - 138ms/epoch - 8ms/step
# Epoch 79/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6633 - val_accuracy: 0.6259 - 135ms/epoch - 8ms/step
# Epoch 80/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6635 - val_accuracy: 0.6259 - 123ms/epoch - 7ms/step
# Epoch 81/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6630 - val_accuracy: 0.6259 - 124ms/epoch - 7ms/step
# Epoch 82/1000
# 18/18 - 0s - loss: 0.6431 - accuracy: 0.6576 - val_loss: 0.6629 - val_accuracy: 0.6259 - 123ms/epoch - 7ms/step
# Epoch 83/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6633 - val_accuracy: 0.6259 - 129ms/epoch - 7ms/step
# Epoch 84/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6638 - val_accuracy: 0.6259 - 134ms/epoch - 7ms/step
# Epoch 85/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6641 - val_accuracy: 0.6259 - 125ms/epoch - 7ms/step
# Epoch 86/1000
# 18/18 - 0s - loss: 0.6428 - accuracy: 0.6576 - val_loss: 0.6634 - val_accuracy: 0.6259 - 125ms/epoch - 7ms/step
# Epoch 87/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6632 - val_accuracy: 0.6259 - 156ms/epoch - 9ms/step
# Epoch 88/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6631 - val_accuracy: 0.6259 - 148ms/epoch - 8ms/step
# Epoch 89/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6629 - val_accuracy: 0.6259 - 152ms/epoch - 8ms/step
# Epoch 90/1000
# 18/18 - 0s - loss: 0.6431 - accuracy: 0.6576 - val_loss: 0.6624 - val_accuracy: 0.6259 - 131ms/epoch - 7ms/step
# Epoch 91/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6626 - val_accuracy: 0.6259 - 126ms/epoch - 7ms/step
# Epoch 92/1000
# 18/18 - 0s - loss: 0.6431 - accuracy: 0.6576 - val_loss: 0.6630 - val_accuracy: 0.6259 - 124ms/epoch - 7ms/step
# Epoch 93/1000
# 18/18 - 0s - loss: 0.6432 - accuracy: 0.6576 - val_loss: 0.6635 - val_accuracy: 0.6259 - 124ms/epoch - 7ms/step
# Epoch 94/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6634 - val_accuracy: 0.6259 - 125ms/epoch - 7ms/step
# Epoch 95/1000
# 18/18 - 0s - loss: 0.6432 - accuracy: 0.6576 - val_loss: 0.6631 - val_accuracy: 0.6259 - 124ms/epoch - 7ms/step
# Epoch 96/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6627 - val_accuracy: 0.6259 - 125ms/epoch - 7ms/step
# Epoch 97/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6630 - val_accuracy: 0.6259 - 125ms/epoch - 7ms/step
# Epoch 98/1000
# 18/18 - 0s - loss: 0.6428 - accuracy: 0.6576 - val_loss: 0.6634 - val_accuracy: 0.6259 - 136ms/epoch - 8ms/step
# Epoch 99/1000
# 18/18 - 0s - loss: 0.6431 - accuracy: 0.6576 - val_loss: 0.6635 - val_accuracy: 0.6259 - 126ms/epoch - 7ms/step
# Epoch 100/1000
# 18/18 - 0s - loss: 0.6428 - accuracy: 0.6576 - val_loss: 0.6629 - val_accuracy: 0.6259 - 125ms/epoch - 7ms/step
# Epoch 101/1000
# 18/18 - 0s - loss: 0.6431 - accuracy: 0.6576 - val_loss: 0.6632 - val_accuracy: 0.6259 - 131ms/epoch - 7ms/step
# Epoch 102/1000
# 18/18 - 0s - loss: 0.6431 - accuracy: 0.6576 - val_loss: 0.6627 - val_accuracy: 0.6259 - 125ms/epoch - 7ms/step
# Epoch 103/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6628 - val_accuracy: 0.6259 - 124ms/epoch - 7ms/step
# Epoch 104/1000
# 18/18 - 0s - loss: 0.6428 - accuracy: 0.6576 - val_loss: 0.6636 - val_accuracy: 0.6259 - 147ms/epoch - 8ms/step
# Epoch 105/1000
# 18/18 - 0s - loss: 0.6433 - accuracy: 0.6576 - val_loss: 0.6640 - val_accuracy: 0.6259 - 124ms/epoch - 7ms/step
# Epoch 106/1000
# 18/18 - 0s - loss: 0.6428 - accuracy: 0.6576 - val_loss: 0.6631 - val_accuracy: 0.6259 - 124ms/epoch - 7ms/step
# Epoch 107/1000
# 18/18 - 0s - loss: 0.6428 - accuracy: 0.6576 - val_loss: 0.6635 - val_accuracy: 0.6259 - 125ms/epoch - 7ms/step
# Epoch 108/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6630 - val_accuracy: 0.6259 - 123ms/epoch - 7ms/step
# Epoch 109/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6627 - val_accuracy: 0.6259 - 125ms/epoch - 7ms/step
# Epoch 110/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6626 - val_accuracy: 0.6259 - 133ms/epoch - 7ms/step
# Epoch 111/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6625 - val_accuracy: 0.6259 - 132ms/epoch - 7ms/step
# Epoch 112/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6628 - val_accuracy: 0.6259 - 124ms/epoch - 7ms/step
# Epoch 113/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6625 - val_accuracy: 0.6259 - 133ms/epoch - 7ms/step
# Epoch 114/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6633 - val_accuracy: 0.6259 - 123ms/epoch - 7ms/step
# Epoch 115/1000
# 18/18 - 0s - loss: 0.6428 - accuracy: 0.6576 - val_loss: 0.6635 - val_accuracy: 0.6259 - 123ms/epoch - 7ms/step
# Epoch 116/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6627 - val_accuracy: 0.6259 - 123ms/epoch - 7ms/step
# Epoch 117/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6625 - val_accuracy: 0.6259 - 124ms/epoch - 7ms/step
# Epoch 118/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6631 - val_accuracy: 0.6259 - 122ms/epoch - 7ms/step
# Epoch 119/1000
# 18/18 - 0s - loss: 0.6432 - accuracy: 0.6576 - val_loss: 0.6632 - val_accuracy: 0.6259 - 147ms/epoch - 8ms/step
# Epoch 120/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6628 - val_accuracy: 0.6259 - 125ms/epoch - 7ms/step
# Epoch 121/1000
# 18/18 - 0s - loss: 0.6428 - accuracy: 0.6576 - val_loss: 0.6627 - val_accuracy: 0.6259 - 122ms/epoch - 7ms/step
# Epoch 122/1000
# 18/18 - 0s - loss: 0.6428 - accuracy: 0.6576 - val_loss: 0.6635 - val_accuracy: 0.6259 - 139ms/epoch - 8ms/step
# Epoch 123/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6634 - val_accuracy: 0.6259 - 135ms/epoch - 7ms/step
# Epoch 124/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6629 - val_accuracy: 0.6259 - 125ms/epoch - 7ms/step
# Epoch 125/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6625 - val_accuracy: 0.6259 - 125ms/epoch - 7ms/step
# Epoch 126/1000
# 18/18 - 0s - loss: 0.6428 - accuracy: 0.6576 - val_loss: 0.6629 - val_accuracy: 0.6259 - 176ms/epoch - 10ms/step
# Epoch 127/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6634 - val_accuracy: 0.6259 - 124ms/epoch - 7ms/step
# Epoch 128/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6632 - val_accuracy: 0.6259 - 125ms/epoch - 7ms/step
# Epoch 129/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6637 - val_accuracy: 0.6259 - 125ms/epoch - 7ms/step
# Epoch 130/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6632 - val_accuracy: 0.6259 - 125ms/epoch - 7ms/step
# Epoch 131/1000
# 18/18 - 0s - loss: 0.6431 - accuracy: 0.6576 - val_loss: 0.6631 - val_accuracy: 0.6259 - 128ms/epoch - 7ms/step
# Epoch 132/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6630 - val_accuracy: 0.6259 - 122ms/epoch - 7ms/step
# Epoch 133/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6632 - val_accuracy: 0.6259 - 136ms/epoch - 8ms/step
# Epoch 134/1000
# 18/18 - 0s - loss: 0.6431 - accuracy: 0.6576 - val_loss: 0.6638 - val_accuracy: 0.6259 - 150ms/epoch - 8ms/step
# Epoch 135/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6637 - val_accuracy: 0.6259 - 130ms/epoch - 7ms/step
# Epoch 136/1000
# 18/18 - 0s - loss: 0.6428 - accuracy: 0.6576 - val_loss: 0.6642 - val_accuracy: 0.6259 - 123ms/epoch - 7ms/step
# Epoch 137/1000
# 18/18 - 0s - loss: 0.6431 - accuracy: 0.6576 - val_loss: 0.6645 - val_accuracy: 0.6259 - 123ms/epoch - 7ms/step
# Epoch 138/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6636 - val_accuracy: 0.6259 - 135ms/epoch - 8ms/step
# Epoch 139/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6628 - val_accuracy: 0.6259 - 123ms/epoch - 7ms/step
# Epoch 140/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6629 - val_accuracy: 0.6259 - 123ms/epoch - 7ms/step
# Epoch 141/1000
# 18/18 - 0s - loss: 0.6428 - accuracy: 0.6576 - val_loss: 0.6629 - val_accuracy: 0.6259 - 134ms/epoch - 7ms/step
# Epoch 142/1000
# 18/18 - 0s - loss: 0.6431 - accuracy: 0.6576 - val_loss: 0.6628 - val_accuracy: 0.6259 - 123ms/epoch - 7ms/step
# Epoch 143/1000
# 18/18 - 0s - loss: 0.6428 - accuracy: 0.6576 - val_loss: 0.6629 - val_accuracy: 0.6259 - 123ms/epoch - 7ms/step
# Epoch 144/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6635 - val_accuracy: 0.6259 - 124ms/epoch - 7ms/step
# Epoch 145/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6634 - val_accuracy: 0.6259 - 123ms/epoch - 7ms/step
# Epoch 146/1000
# 18/18 - 0s - loss: 0.6431 - accuracy: 0.6576 - val_loss: 0.6634 - val_accuracy: 0.6259 - 123ms/epoch - 7ms/step
# Epoch 147/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6625 - val_accuracy: 0.6259 - 124ms/epoch - 7ms/step
# Epoch 148/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6634 - val_accuracy: 0.6259 - 127ms/epoch - 7ms/step
# Epoch 149/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6631 - val_accuracy: 0.6259 - 124ms/epoch - 7ms/step
# Epoch 150/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6628 - val_accuracy: 0.6259 - 125ms/epoch - 7ms/step
# Epoch 151/1000
# 18/18 - 0s - loss: 0.6431 - accuracy: 0.6576 - val_loss: 0.6625 - val_accuracy: 0.6259 - 125ms/epoch - 7ms/step
# Epoch 152/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6632 - val_accuracy: 0.6259 - 124ms/epoch - 7ms/step
# Epoch 153/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6636 - val_accuracy: 0.6259 - 123ms/epoch - 7ms/step
# Epoch 154/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6631 - val_accuracy: 0.6259 - 124ms/epoch - 7ms/step
# Epoch 155/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6635 - val_accuracy: 0.6259 - 134ms/epoch - 7ms/step
# Epoch 156/1000
# 18/18 - 0s - loss: 0.6431 - accuracy: 0.6576 - val_loss: 0.6629 - val_accuracy: 0.6259 - 144ms/epoch - 8ms/step
# Epoch 157/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6626 - val_accuracy: 0.6259 - 124ms/epoch - 7ms/step
# Epoch 158/1000
# 18/18 - 0s - loss: 0.6431 - accuracy: 0.6576 - val_loss: 0.6632 - val_accuracy: 0.6259 - 123ms/epoch - 7ms/step
# Epoch 159/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6629 - val_accuracy: 0.6259 - 126ms/epoch - 7ms/step
# Epoch 160/1000
# 18/18 - 0s - loss: 0.6432 - accuracy: 0.6576 - val_loss: 0.6632 - val_accuracy: 0.6259 - 150ms/epoch - 8ms/step
# Epoch 161/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6631 - val_accuracy: 0.6259 - 159ms/epoch - 9ms/step
# Epoch 162/1000
# 18/18 - 0s - loss: 0.6428 - accuracy: 0.6576 - val_loss: 0.6627 - val_accuracy: 0.6259 - 145ms/epoch - 8ms/step
# Epoch 163/1000
# 18/18 - 0s - loss: 0.6431 - accuracy: 0.6576 - val_loss: 0.6630 - val_accuracy: 0.6259 - 124ms/epoch - 7ms/step
# Epoch 164/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6633 - val_accuracy: 0.6259 - 128ms/epoch - 7ms/step
# Epoch 165/1000
# 18/18 - 0s - loss: 0.6431 - accuracy: 0.6576 - val_loss: 0.6628 - val_accuracy: 0.6259 - 132ms/epoch - 7ms/step
# Epoch 166/1000
# 18/18 - 0s - loss: 0.6428 - accuracy: 0.6576 - val_loss: 0.6630 - val_accuracy: 0.6259 - 126ms/epoch - 7ms/step
# Epoch 167/1000
# 18/18 - 0s - loss: 0.6433 - accuracy: 0.6576 - val_loss: 0.6632 - val_accuracy: 0.6259 - 130ms/epoch - 7ms/step
# Epoch 168/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6639 - val_accuracy: 0.6259 - 125ms/epoch - 7ms/step
# Epoch 169/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6633 - val_accuracy: 0.6259 - 123ms/epoch - 7ms/step
# Epoch 170/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6635 - val_accuracy: 0.6259 - 126ms/epoch - 7ms/step
# Epoch 171/1000
# 18/18 - 0s - loss: 0.6431 - accuracy: 0.6576 - val_loss: 0.6640 - val_accuracy: 0.6259 - 141ms/epoch - 8ms/step
# Epoch 172/1000
# 18/18 - 0s - loss: 0.6430 - accuracy: 0.6576 - val_loss: 0.6633 - val_accuracy: 0.6259 - 128ms/epoch - 7ms/step
# Epoch 173/1000
# 18/18 - 0s - loss: 0.6429 - accuracy: 0.6576 - val_loss: 0.6639 - val_accuracy: 0.6259 - 123ms/epoch - 7ms/step
# Epoch 174/1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/anvu/Workspace/Master/DeepLearningFoundation/withimpute.ipynb Cell 18 line 1
#       <a href='vscode-notebook-cell:/Users/anvu/Workspace/Master/DeepLearningFoundation/withimpute.ipynb#X36sZmlsZQ%3D%3D?line=2'>3</a> early_stopping = tf.keras.callbacks.EarlyStopping(
#       <a href='vscode-notebook-cell:/Users/anvu/Workspace/Master/DeepLearningFoundation/withimpute.ipynb#X36sZmlsZQ%3D%3D?line=3'>4</a>     monitor='val_loss',
#       <a href='vscode-notebook-cell:/Users/anvu/Workspace/Master/DeepLearningFoundation/withimpute.ipynb#X36sZmlsZQ%3D%3D?line=4'>5</a>     verbose=1,
#       <a href='vscode-notebook-cell:/Users/anvu/Workspace/Master/DeepLearningFoundation/withimpute.ipynb#X36sZmlsZQ%3D%3D?line=5'>6</a>     patience=100,
#       <a href='vscode-notebook-cell:/Users/anvu/Workspace/Master/DeepLearningFoundation/withimpute.ipynb#X36sZmlsZQ%3D%3D?line=6'>7</a>     mode='min',
#       <a href='vscode-notebook-cell:/Users/anvu/Workspace/Master/DeepLearningFoundation/withimpute.ipynb#X36sZmlsZQ%3D%3D?line=7'>8</a>     restore_best_weights=True)
#       <a href='vscode-notebook-cell:/Users/anvu/Workspace/Master/DeepLearningFoundation/withimpute.ipynb#X36sZmlsZQ%3D%3D?line=8'>9</a> model = create_model()
# ---> <a href='vscode-notebook-cell:/Users/anvu/Workspace/Master/DeepLearningFoundation/withimpute.ipynb#X36sZmlsZQ%3D%3D?line=9'>10</a> model.fit(X_train,Y_train, validation_split=.2, epochs = 1000, verbose = 2)
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/keras/engine/training.py:1685, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1677 with tf.profiler.experimental.Trace(
#    1678     "train",
#    1679     epoch_num=epoch,
#    (...)
#    1682     _r=1,
#    1683 ):
#    1684     callbacks.on_train_batch_begin(step)
# -> 1685     tmp_logs = self.train_function(iterator)
#    1686     if data_handler.should_sync:
#    1687         context.async_wait()
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:894, in Function.__call__(self, *args, **kwds)
#     891 compiler = "xla" if self._jit_compile else "nonXla"
#     893 with OptionalXlaContext(self._jit_compile):
# --> 894   result = self._call(*args, **kwds)
#     896 new_tracing_count = self.experimental_get_tracing_count()
#     897 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:926, in Function._call(self, *args, **kwds)
#     923   self._lock.release()
#     924   # In this case we have created variables on the first call, so we run the
#     925   # defunned version which is guaranteed to never create variables.
# --> 926   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     927 elif self._variable_creation_fn is not None:
#     928   # Release the lock early so that multiple threads can perform the call
#     929   # in parallel.
#     930   self._lock.release()
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:143, in TracingCompiler.__call__(self, *args, **kwargs)
#     140 with self._lock:
#     141   (concrete_function,
#     142    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143 return concrete_function._call_flat(
#     144     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1757, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1753 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1754 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1755     and executing_eagerly):
#    1756   # No tape is watching; skip to running the function.
# -> 1757   return self._build_call_outputs(self._inference_function.call(
#    1758       ctx, args, cancellation_manager=cancellation_manager))
#    1759 forward_backward = self._select_forward_and_backward_functions(
#    1760     args,
#    1761     possible_gradient_type,
#    1762     executing_eagerly)
#    1763 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:381, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     379 with _InterpolateFunctionError(self):
#     380   if cancellation_manager is None:
# --> 381     outputs = execute.execute(
#     382         str(self.signature.name),
#     383         num_outputs=self._num_outputs,
#     384         inputs=args,
#     385         attrs=attrs,
#     386         ctx=ctx)
#     387   else:
#     388     outputs = execute.execute_with_cancellation(
#     389         str(self.signature.name),
#     390         num_outputs=self._num_outputs,
#    (...)
#     393         ctx=ctx,
#     394         cancellation_manager=cancellation_manager)
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:

# %%
model.evaluate(X_test, Y_test)
# Out:
# 3/3 [==============================] - 0s 61ms/step - loss: 0.6480 - accuracy: 0.6494
# [0.6480262279510498, 0.649350643157959]
